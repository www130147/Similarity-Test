# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa top lightsheet outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa top confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (9, 9), 0)
blurred_image2 = cv.GaussianBlur(image2, (9, 9), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.1:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Treated Sec1 LSFM Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Treated Sec1 CLSM Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.0276065953515634
# The two images have similar morphology.
# Hu moments difference: 0.007260233189374362

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa btm lightsheet outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa btm confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (7, 7), 0)
blurred_image2 = cv.GaussianBlur(image2, (7, 7), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.1:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Treated Sec2 LSFM Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Treated Sec2 CLSM Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.0
# The two images have similar morphology.
# Hu moments difference: 4.898148155758528e-16

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal top lightsheet outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal top confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (5, 5), 0)
blurred_image2 = cv.GaussianBlur(image2, (5, 5), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Control Sec1 LSFM Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Control Sec1 CLSM Edges')


plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 1.2838301976514366e-06
# The two images have similar morphology.
# Hu moments difference: 9.614086256128496e-09

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal btm lightsheet outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal btm confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (5, 5), 0)
blurred_image2 = cv.GaussianBlur(image2, (5, 5), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Control Sec2 LSFM Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Control Sec2 CLSM Edges')


plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.0
# The two images have similar morphology.
# Hu moments difference: 6.359935749606812e-16

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa top confocal outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa btm confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (3, 3), 0)
blurred_image2 = cv.GaussianBlur(image2, (3, 3), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Treated Sec1 Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Treated Sec2 Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.09823195664735995
# The two images have different morphology.
# Hu moments difference: 0.027372583859099322

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal top confocal outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa top confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (5, 5), 0)
blurred_image2 = cv.GaussianBlur(image2, (5, 5), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Control Sec1 Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Treated Sec1 Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.11221869156808173
# The two images have different morphology.
# Hu moments difference: 0.012568344305981433

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal top confocal outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/dmxaa btm confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (5, 5), 0)
blurred_image2 = cv.GaussianBlur(image2, (5, 5), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Control Sec1 Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Treated Sec2 Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.05412590398276684
# The two images have different morphology.
# Hu moments difference: 0.015566642564889464

# %%
#可以给outline用的算法

image1=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal top confocal outline.tif', cv.IMREAD_GRAYSCALE)
image2=cv.imread(r'/Users/jingtianzheng/Documents/uic phd/lab5/project/light-sheet/paper/reverse/new data/similarity/outline/normal btm confocal outline.tif', cv.IMREAD_GRAYSCALE)

#blurred_image1 = cv.bilateralFilter(image1, d=9, sigmaColor=75, sigmaSpace=75)
#blurred_image2 = cv.bilateralFilter(image2, d=9, sigmaColor=75, sigmaSpace=75)
blurred_image1 = cv.GaussianBlur(image1, (5, 5), 0)
blurred_image2 = cv.GaussianBlur(image2, (5, 5), 0)


edges1 = cv.Canny(blurred_image1, 100, 200)
edges2 = cv.Canny(blurred_image2, 100, 200)

# 找到轮廓
contours1, _ = cv.findContours(edges1, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)
contours2, _ = cv.findContours(edges2, cv.RETR_EXTERNAL, cv.CHAIN_APPROX_SIMPLE)

# 假设每张图像只有一个主要轮廓，选择第一个轮廓进行比较
contour1 = contours1[0] if len(contours1) > 0 else None
contour2 = contours2[0] if len(contours2) > 0 else None

# 使用 cv2.matchShapes 比较轮廓的形状相似性
if contour1 is not None and contour2 is not None:
    similarity = cv.matchShapes(contour1, contour2, cv.CONTOURS_MATCH_I1, 0.0)
    print(f"Shape similarity (lower is better): {similarity}")

    if similarity < 0.05:  # 可以根据需要调整阈值
        print("The two images have similar morphology.")
    else:
        print("The two images have different morphology.")
else:
    print("Unable to find contours in one or both images.")

# 显示原始图像和边缘检测结果
plt.subplot(1, 2, 1)
plt.imshow(edges1, cmap='gray')
plt.title('Control Sec1 Edges')

plt.subplot(1, 2, 2)
plt.imshow(edges2, cmap='gray')
plt.title('Control Sec2 Edges')

plt.show()
# 计算 Hu 矩
moments1 = cv.moments(contour1)
moments2 = cv.moments(contour2)

hu_moments1 = cv.HuMoments(moments1).flatten()
hu_moments2 = cv.HuMoments(moments2).flatten()

# 比较 Hu 矩
difference = np.sum(np.abs(hu_moments1 - hu_moments2))
print(f"Hu moments difference: {difference}")
# Out:
# Shape similarity (lower is better): 0.05412590398276684
# The two images have different morphology.
# Hu moments difference: 0.015566642564889575
